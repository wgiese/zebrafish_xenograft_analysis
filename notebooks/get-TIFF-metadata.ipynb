# %%
import h5py
import numpy as np
from matplotlib import pyplot as plt
import scipy.ndimage
import os
import pandas as pd
import imageio
from skimage import io
from skimage.filters import threshold_otsu
from scipy.ndimage import gaussian_filter
import matplotlib
import yaml

font = {'family': 'normal', 'weight' : 'bold', 'size' : 22}
matplotlib.rc('font', **font)

# %% [markdown]
# # read parameters

# %%
with open("../base/parameters.yml") as file:
    parameters = yaml.load(file, Loader=yaml.FullLoader)
with open("../local/parameters.yml") as file:
    parameters_local = yaml.load(file, Loader=yaml.FullLoader)

# overwrite global parameters with local setting
for key in parameters_local:
    parameters[key] = parameters_local[key]
    
print(parameters)
# Out:
# {'data_folder': '/home/ebauman/Data/zebrafish_xenograft/', 'output_folder': '/home/ebauman/Data/zebrafish_xenograft/', 'output_filename': 'image_001', 'dimension': '2D', 'otsu_thresholding': False, 'sigma': 1, 'segmentation_method': 'ilastik', 'macrophages_small_objects': 2500, 'key_file_name': 'Details_imaging_data_2D.xls', 'csv_path': '/home/ebauman/Data/zebrafish_xenograft/04_Processed_Data/01_Annotated_Macrophages/'}

# %% [markdown]
# # read TIFF metadata with PIL

# %%
data_folder = parameters["data_folder"] + "03_Preprocessed_Data/3D/"
file = "200804_LBT070_1dpi_Pos001.tif"

import PIL
meta_data = dict()
img = PIL.Image.open(data_folder + file)

for key in img.tag.tagdata:
    print(img.tag.tagdata[key])
           
    tag_data = str(img.tag.tagdata[key])

    if tag_data.find("xml")>0:
        data = tag_data.split(" ")

        for d in data:
            attribute = d.split("=")[0]
            if attribute in float_attributes:
                meta_data[attribute] = float(d.split("=")[1].replace('"',''))
            if attribute in int_attributes:
                meta_data[attribute] = int(d.split("=")[1].replace('"',''))
    
    
print(meta_data)
img_npArray = np.array(io.imread(data_folder + file))
print(img_npArray.shape)
# Out:
# b'\x00\x00\x00\x00'
# b'\x00\x00\x04\x00'
# b'\x00\x00\x04\x00'
# b'\x00\x08'
# b'\x00\x03'
# b'ImageJ=1.52n\nimages=12672\nchannels=3\nslices=128\nframes=33\nhyperstack=true\nmode=composite\nunit=micron\nfinterval=1800.0855712890625\nspacing=1.0184\nloop=false\nmin=17.0\nmax=34.0\n\x00'
# b'\x00\x00\x10\xe5'
# b'\x00\x01'
# b'\x04\x00'
# b'\x00\x10\x00\x00'
# b'\x00#?p\x00\x0fB@'
# b'\x00#?p\x00\x0fB@'
# b'\x00\x01'
# ...

# %% [markdown]
# # read TIFF metadata with bioformats

# %%
data_folder = parameters["data_folder"] + "03_Processed_Data/3D/"
file = "200804_LBT070_1dpi_Pos001.tif"

import bioformats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-6dea019c9ad3> in <module>
#       2 file = "200804_LBT070_1dpi_Pos001.tif"
#       3
# ----> 4 import bioformats
#
# ModuleNotFoundError: No module named 'bioformats'
